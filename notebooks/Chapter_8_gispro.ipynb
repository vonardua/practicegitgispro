# %%
num_points = 120

# %%
print (num_points)
# Out:
# 120

# %%
num_points
# Out:
# 120

# %%
location_data = 42.3601

location_data = "Boston"

location_data = [42.3601, -71.0589]

print(location_data)
# Out:
# [42.3601, -71.0589]

# %%
latitude = 42.3601
longitude = -71.0589
elevation = 147.2
city_name = "Boston"
population = 685094
coordinate_system = "WGS 84"

# %%
print ("Hello World!\nThis is a Python script")

print ("This is the first line.\n\t This is the second line. It is indented")

print ("What's your name?")

print ('What\'s your name?')
# Out:
# Hello World!
# This is a Python script
# This is the first line.
# 	 This is the second line. It is indented
# What's your name?
# What's your name?

# %%
num_features = 20
print("updated number of features", num_features)
# Out:
# updated number of features 20

# %%
import math

latitude = 35.6895
latitude_radians = math.radians (latitude)
print ("latitude in radians:", latitude_radians)
# Out:
# latitude in radians: 0.6228992833905163

# %%
feature_attributes = {
    "Name": "Mount Fuji",
    "height_meters": 3776,
    "type": "Stratovolcano",
    "location": [35.3606, 138.7274]
}

# %%
print(feature_attributes["height_meters"])
# Out:
# 3776

# %%
mount_fuji_name = feature_attributes["Name"]
mount_fuji_height = feature_attributes["height_meters"]
print(f"{mount_fuji_name} is {mount_fuji_height} meters high.")
# Out:
# Mount Fuji is 3776 meters high.

# %%
city_name= "San Francisco"
city_title = city_name.title()
print ("Lowercase:", city_title)
# Out:
# Lowercase: San Francisco

# %%
original_city = "San Francisco"
new_city = original_city.replace("San", "Los")
print ("Original", original_city)
print ("Modified:", new_city)
# Out:
# Original San Francisco
# Modified: Los Francisco

# %%
location_data = "   Mount Everest    "
clean_location = location_data.strip()
print("Cleaned:", clean_location)
# Out:
# Cleaned: Mount Everest

# %%
latitude_nyc= 40.7128 
longitude_nyc= -74.0060
population_nyc= 8336817
area_sqm_nyc= 783.8

population_density_nyc= (population_nyc//area_sqm_nyc) 
print("The population density of New York City in square meters is:", population_density_nyc)
print("latitude:", latitude_nyc,"longitude:",longitude)
# Out:
# The population density of New York City in square meters is: 10636.0
# latitude: 40.7128 longitude: -71.0589

# %%
city_name= "New York City"

city_replace= city_name.replace("New York", "Los Angeles")
print(city_replace)
# Out:
# Los Angeles City
